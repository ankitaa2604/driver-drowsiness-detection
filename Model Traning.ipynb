# %%
import tensorflow as tf
from tensorflow.keras.applications import InceptionV3
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Dropout,Input,Flatten,Dense,MaxPooling2D
from tensorflow.keras.preprocessing.image import ImageDataGenerator  # Data Augumentation

# %%
train_datagen= ImageDataGenerator(rescale=1./255, rotation_range=0.2,shear_range=0.2,
    zoom_range=0.2,width_shift_range=0.2,
    height_shift_range=0.2, validation_split=0.2)

# %%
batchsize=8

# %%
train_data= train_datagen.flow_from_directory(r'D:\dataset\Prepared_Data\train',
                                target_size=(80,80),batch_size=batchsize,class_mode='categorical',subset='training' )

validation_data= train_datagen.flow_from_directory(r'D:\dataset\Prepared_Data\train',
                                target_size=(80,80),batch_size=batchsize,class_mode='categorical',subset='validation')
# Out:
# Found 64143 images belonging to 2 classes.
# Found 16035 images belonging to 2 classes.

# %%
test_datagen = ImageDataGenerator(rescale=1./255)

test_data = test_datagen.flow_from_directory(r'D:\dataset\Prepared_Data\test',
                                target_size=(80,80),batch_size=batchsize,class_mode='categorical')
# Out:
# Found 4720 images belonging to 2 classes.

# %%
bmodel = InceptionV3(include_top=False, weights='imagenet', input_tensor=Input(shape=(80,80,3), batch_size=batchsize))
hmodel = bmodel.output

# %%
bmodel.summary()
# Out:
# Model: "inception_v3"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_2 (InputLayer)           [(8, 80, 80, 3)]     0           []
#
#  conv2d_94 (Conv2D)             (8, 39, 39, 32)      864         ['input_2[0][0]']
#
#  batch_normalization_94 (BatchN  (8, 39, 39, 32)     96          ['conv2d_94[0][0]']
#  ormalization)
#
#  activation_94 (Activation)     (8, 39, 39, 32)      0           ['batch_normalization_94[0][0]']
#
#  conv2d_95 (Conv2D)             (8, 37, 37, 32)      9216        ['activation_94[0][0]']
#
#  batch_normalization_95 (BatchN  (8, 37, 37, 32)     96          ['conv2d_95[0][0]']
#  ormalization)
#
#  activation_95 (Activation)     (8, 37, 37, 32)      0           ['batch_normalization_95[0][0]']
#
#  conv2d_96 (Conv2D)             (8, 37, 37, 64)      18432       ['activation_95[0][0]']
#
#  batch_normalization_96 (BatchN  (8, 37, 37, 64)     192         ['conv2d_96[0][0]']
#  ormalization)
#
#  activation_96 (Activation)     (8, 37, 37, 64)      0           ['batch_normalization_96[0][0]']
#
#  max_pooling2d_4 (MaxPooling2D)  (8, 18, 18, 64)     0           ['activation_96[0][0]']
#
#  conv2d_97 (Conv2D)             (8, 18, 18, 80)      5120        ['max_pooling2d_4[0][0]']
#
#  batch_normalization_97 (BatchN  (8, 18, 18, 80)     240         ['conv2d_97[0][0]']
#  ormalization)
#
#  activation_97 (Activation)     (8, 18, 18, 80)      0           ['batch_normalization_97[0][0]']
#
#  conv2d_98 (Conv2D)             (8, 16, 16, 192)     138240      ['activation_97[0][0]']
#
#  batch_normalization_98 (BatchN  (8, 16, 16, 192)    576         ['conv2d_98[0][0]']
#  ormalization)
#
#  activation_98 (Activation)     (8, 16, 16, 192)     0           ['batch_normalization_98[0][0]']
#
#  max_pooling2d_5 (MaxPooling2D)  (8, 7, 7, 192)      0           ['activation_98[0][0]']
#
#  conv2d_102 (Conv2D)            (8, 7, 7, 64)        12288       ['max_pooling2d_5[0][0]']
#
#  batch_normalization_102 (Batch  (8, 7, 7, 64)       192         ['conv2d_102[0][0]']
#  Normalization)
#
#  activation_102 (Activation)    (8, 7, 7, 64)        0           ['batch_normalization_102[0][0]']
#
#  conv2d_100 (Conv2D)            (8, 7, 7, 48)        9216        ['max_pooling2d_5[0][0]']
#
#  conv2d_103 (Conv2D)            (8, 7, 7, 96)        55296       ['activation_102[0][0]']
#
#  batch_normalization_100 (Batch  (8, 7, 7, 48)       144         ['conv2d_100[0][0]']
#  Normalization)
#
#  batch_normalization_103 (Batch  (8, 7, 7, 96)       288         ['conv2d_103[0][0]']
#  Normalization)
#
#  activation_100 (Activation)    (8, 7, 7, 48)        0           ['batch_normalization_100[0][0]']
#
#  activation_103 (Activation)    (8, 7, 7, 96)        0           ['batch_normalization_103[0][0]']
#
#  average_pooling2d_9 (AveragePo  (8, 7, 7, 192)      0           ['max_pooling2d_5[0][0]']
#  oling2D)
#
#  conv2d_99 (Conv2D)             (8, 7, 7, 64)        12288       ['max_pooling2d_5[0][0]']
#
#  conv2d_101 (Conv2D)            (8, 7, 7, 64)        76800       ['activation_100[0][0]']
#
#  conv2d_104 (Conv2D)            (8, 7, 7, 96)        82944       ['activation_103[0][0]']
#
#  conv2d_105 (Conv2D)            (8, 7, 7, 32)        6144        ['average_pooling2d_9[0][0]']
#
#  batch_normalization_99 (BatchN  (8, 7, 7, 64)       192         ['conv2d_99[0][0]']
#  ormalization)
#
#  batch_normalization_101 (Batch  (8, 7, 7, 64)       192         ['conv2d_101[0][0]']
#  Normalization)
#
#  batch_normalization_104 (Batch  (8, 7, 7, 96)       288         ['conv2d_104[0][0]']
#  Normalization)
#
#  batch_normalization_105 (Batch  (8, 7, 7, 32)       96          ['conv2d_105[0][0]']
#  Normalization)
#
#  activation_99 (Activation)     (8, 7, 7, 64)        0           ['batch_normalization_99[0][0]']
#
#  activation_101 (Activation)    (8, 7, 7, 64)        0           ['batch_normalization_101[0][0]']
#
#  activation_104 (Activation)    (8, 7, 7, 96)        0           ['batch_normalization_104[0][0]']
#
#  activation_105 (Activation)    (8, 7, 7, 32)        0           ['batch_normalization_105[0][0]']
#
#  mixed0 (Concatenate)           (8, 7, 7, 256)       0           ['activation_99[0][0]',
#                                                                   'activation_101[0][0]',
#                                                                   'activation_104[0][0]',
#                                                                   'activation_105[0][0]']
#
#  conv2d_109 (Conv2D)            (8, 7, 7, 64)        16384       ['mixed0[0][0]']
#
#  batch_normalization_109 (Batch  (8, 7, 7, 64)       192         ['conv2d_109[0][0]']
#  Normalization)
#
#  activation_109 (Activation)    (8, 7, 7, 64)        0           ['batch_normalization_109[0][0]']
#
#  conv2d_107 (Conv2D)            (8, 7, 7, 48)        12288       ['mixed0[0][0]']
#
#  conv2d_110 (Conv2D)            (8, 7, 7, 96)        55296       ['activation_109[0][0]']
#
#  batch_normalization_107 (Batch  (8, 7, 7, 48)       144         ['conv2d_107[0][0]']
#  Normalization)
#
#  batch_normalization_110 (Batch  (8, 7, 7, 96)       288         ['conv2d_110[0][0]']
#  Normalization)
#
#  activation_107 (Activation)    (8, 7, 7, 48)        0           ['batch_normalization_107[0][0]']
#
#  activation_110 (Activation)    (8, 7, 7, 96)        0           ['batch_normalization_110[0][0]']
#
#  average_pooling2d_10 (AverageP  (8, 7, 7, 256)      0           ['mixed0[0][0]']
#  ooling2D)
#
#  conv2d_106 (Conv2D)            (8, 7, 7, 64)        16384       ['mixed0[0][0]']
#
#  conv2d_108 (Conv2D)            (8, 7, 7, 64)        76800       ['activation_107[0][0]']
#
#  conv2d_111 (Conv2D)            (8, 7, 7, 96)        82944       ['activation_110[0][0]']
#
#  conv2d_112 (Conv2D)            (8, 7, 7, 64)        16384       ['average_pooling2d_10[0][0]']
#
#  batch_normalization_106 (Batch  (8, 7, 7, 64)       192         ['conv2d_106[0][0]']
#  Normalization)
#
#  batch_normalization_108 (Batch  (8, 7, 7, 64)       192         ['conv2d_108[0][0]']
#  Normalization)
#
#  batch_normalization_111 (Batch  (8, 7, 7, 96)       288         ['conv2d_111[0][0]']
#  Normalization)
#
#  batch_normalization_112 (Batch  (8, 7, 7, 64)       192         ['conv2d_112[0][0]']
#  Normalization)
#
#  activation_106 (Activation)    (8, 7, 7, 64)        0           ['batch_normalization_106[0][0]']
#
#  activation_108 (Activation)    (8, 7, 7, 64)        0           ['batch_normalization_108[0][0]']
#
#  activation_111 (Activation)    (8, 7, 7, 96)        0           ['batch_normalization_111[0][0]']
#
#  activation_112 (Activation)    (8, 7, 7, 64)        0           ['batch_normalization_112[0][0]']
#
#  mixed1 (Concatenate)           (8, 7, 7, 288)       0           ['activation_106[0][0]',
#                                                                   'activation_108[0][0]',
#                                                                   'activation_111[0][0]',
#                                                                   'activation_112[0][0]']
#
#  conv2d_116 (Conv2D)            (8, 7, 7, 64)        18432       ['mixed1[0][0]']
#
#  batch_normalization_116 (Batch  (8, 7, 7, 64)       192         ['conv2d_116[0][0]']
#  Normalization)
#
#  activation_116 (Activation)    (8, 7, 7, 64)        0           ['batch_normalization_116[0][0]']
#
#  conv2d_114 (Conv2D)            (8, 7, 7, 48)        13824       ['mixed1[0][0]']
#
#  conv2d_117 (Conv2D)            (8, 7, 7, 96)        55296       ['activation_116[0][0]']
#
#  batch_normalization_114 (Batch  (8, 7, 7, 48)       144         ['conv2d_114[0][0]']
#  Normalization)
#
#  batch_normalization_117 (Batch  (8, 7, 7, 96)       288         ['conv2d_117[0][0]']
#  Normalization)
#
#  activation_114 (Activation)    (8, 7, 7, 48)        0           ['batch_normalization_114[0][0]']
#
#  activation_117 (Activation)    (8, 7, 7, 96)        0           ['batch_normalization_117[0][0]']
#
#  average_pooling2d_11 (AverageP  (8, 7, 7, 288)      0           ['mixed1[0][0]']
#  ooling2D)
#
#  conv2d_113 (Conv2D)            (8, 7, 7, 64)        18432       ['mixed1[0][0]']
#
#  conv2d_115 (Conv2D)            (8, 7, 7, 64)        76800       ['activation_114[0][0]']
#
#  conv2d_118 (Conv2D)            (8, 7, 7, 96)        82944       ['activation_117[0][0]']
#
#  conv2d_119 (Conv2D)            (8, 7, 7, 64)        18432       ['average_pooling2d_11[0][0]']
#
#  batch_normalization_113 (Batch  (8, 7, 7, 64)       192         ['conv2d_113[0][0]']
#  Normalization)
#
#  batch_normalization_115 (Batch  (8, 7, 7, 64)       192         ['conv2d_115[0][0]']
#  Normalization)
#
#  batch_normalization_118 (Batch  (8, 7, 7, 96)       288         ['conv2d_118[0][0]']
#  Normalization)
#
#  batch_normalization_119 (Batch  (8, 7, 7, 64)       192         ['conv2d_119[0][0]']
#  Normalization)
#
#  activation_113 (Activation)    (8, 7, 7, 64)        0           ['batch_normalization_113[0][0]']
#
#  activation_115 (Activation)    (8, 7, 7, 64)        0           ['batch_normalization_115[0][0]']
#
#  activation_118 (Activation)    (8, 7, 7, 96)        0           ['batch_normalization_118[0][0]']
#
#  activation_119 (Activation)    (8, 7, 7, 64)        0           ['batch_normalization_119[0][0]']
#
#  mixed2 (Concatenate)           (8, 7, 7, 288)       0           ['activation_113[0][0]',
#                                                                   'activation_115[0][0]',
#                                                                   'activation_118[0][0]',
#                                                                   'activation_119[0][0]']
#
#  conv2d_121 (Conv2D)            (8, 7, 7, 64)        18432       ['mixed2[0][0]']
#
#  batch_normalization_121 (Batch  (8, 7, 7, 64)       192         ['conv2d_121[0][0]']
#  Normalization)
#
#  activation_121 (Activation)    (8, 7, 7, 64)        0           ['batch_normalization_121[0][0]']
#
#  conv2d_122 (Conv2D)            (8, 7, 7, 96)        55296       ['activation_121[0][0]']
#
#  batch_normalization_122 (Batch  (8, 7, 7, 96)       288         ['conv2d_122[0][0]']
#  Normalization)
#
#  activation_122 (Activation)    (8, 7, 7, 96)        0           ['batch_normalization_122[0][0]']
#
#  conv2d_120 (Conv2D)            
         ['conv2d_135[0][0]']
#  Normalization)
#
#  batch_normalization_140 (Batch  (8, 3, 3, 160)      480         ['conv2d_140[0][0]']
#  Normalization)
#
#  activation_135 (Activation)    (8, 3, 3, 160)       0           ['batch_normalization_135[0][0]']
#
#  activation_140 (Activation)    (8, 3, 3, 160)       0           ['batch_normalization_140[0][0]']
#
#  conv2d_136 (Conv2D)            (8, 3, 3, 160)       179200      ['activation_135[0][0]']
#
#  conv2d_141 (Conv2D)            (8, 3, 3, 160)       179200      ['activation_140[0][0]']
#
#  batch_normalization_136 (Batch  (8, 3, 3, 160)      480         ['conv2d_136[0][0]']
#  Normalization)
#
#  batch_normalization_141 (Batch  (8, 3, 3, 160)      480         ['conv2d_141[0][0]']
#  Normalization)
#
#  activation_136 (Activation)    (8, 3, 3, 160)       0           ['batch_normalization_136[0][0]']
#
#  activation_141 (Activation)    (8, 3, 3, 160)       0           ['batch_normalization_141[0][0]']
#
#  average_pooling2d_13 (AverageP  (8, 3, 3, 768)      0           ['mixed4[0][0]']
#  ooling2D)
#
#  conv2d_134 (Conv2D)            (8, 3, 3, 192)       147456      ['mixed4[0][0]']
#
#  conv2d_137 (Conv2D)            (8, 3, 3, 192)       215040      ['activation_136[0][0]']
#
#  conv2d_142 (Conv2D)            (8, 3, 3, 192)       215040      ['activation_141[0][0]']
#
#  conv2d_143 (Conv2D)            (8, 3, 3, 192)       147456      ['average_pooling2d_13[0][0]']
#
#  batch_normalization_134 (Batch  (8, 3, 3, 192)      576         ['conv2d_134[0][0]']
#  Normalization)
#
#  batch_normalization_137 (Batch  (8, 3, 3, 192)      576         ['conv2d_137[0][0]']
#  Normalization)
#
#  batch_normalization_142 (Batch  (8, 3, 3, 192)      576         ['conv2d_142[0][0]']
#  Normalization)
#
#  batch_normalization_143 (Batch  (8, 3, 3, 192)      576         ['conv2d_143[0][0]']
#  Normalization)
#
#  activation_134 (Activation)    (8, 3, 3, 192)       0           ['batch_normalization_134[0][0]']
#
#  activation_137 (Activation)    (8, 3, 3, 192)       0           ['batch_normalization_137[0][0]']
#
#  activation_142 (Activation)    (8, 3, 3, 192)       0           ['batch_normalization_142[0][0]']
#
#  activation_143 (Activation)    (8, 3, 3, 192)       0           ['batch_normalization_143[0][0]']
#
#  mixed5 (Concatenate)           (8, 3, 3, 768)       0           ['activation_134[0][0]',
#                                                                   'activation_137[0][0]',
#                                                                   'activation_142[0][0]',
#                                                                   'activation_143[0][0]']
#
#  conv2d_148 (Conv2D)            (8, 3, 3, 160)       122880      ['mixed5[0][0]']
#
#  batch_normalization_148 (Batch  (8, 3, 3, 160)      480         ['conv2d_148[0][0]']
#  Normalization)
#
#  activation_148 (Activation)    (8, 3, 3, 160)       0           ['batch_normalization_148[0][0]']
#
#  conv2d_149 (Conv2D)            (8, 3, 3, 160)       179200      ['activation_148[0][0]']
#
#  batch_normalization_149 (Batch  (8, 3, 3, 160)      480         ['conv2d_149[0][0]']
#  Normalization)
#
#  activation_149 (Activation)    (8, 3, 3, 160)       0           ['batch_normalization_149[0][0]']
#
#  conv2d_145 (Conv2D)            (8, 3, 3, 160)       122880      ['mixed5[0][0]']
#
#  conv2d_150 (Conv2D)            (8, 3, 3, 160)       179200      ['activation_149[0][0]']
#
#  batch_normalization_145 (Batch  (8, 3, 3, 160)      480         ['conv2d_145[0][0]']
#  Normalization)
#
#  batch_normalization_150 (Batch  (8, 3, 3, 160)      480         ['conv2d_150[0][0]']
#  Normalization)
#
#  activation_145 (Activation)    (8, 3, 3, 160)       0           ['batch_normalization_145[0][0]']
#
#  activation_150 (Activation)    (8, 3, 3, 160)       0           ['batch_normalization_150[0][0]']
#
#  conv2d_146 (Conv2D)            (8, 3, 3, 160)       179200      ['activation_145[0][0]']
#
#  conv2d_151 (Conv2D)            (8, 3, 3, 160)       179200      ['activation_150[0][0]']
#
#  batch_normalization_146 (Batch  (8, 3, 3, 160)      480         ['conv2d_146[0][0]']
#  Normalization)
#
#  batch_normalization_151 (Batch  (8, 3, 3, 160)      480         ['conv2d_151[0][0]']
#  Normalization)
#
#  activation_146 (Activation)    (8, 3, 3, 160)       0           ['batch_normalization_146[0][0]']
#
#  activation_151 (Activation)    (8, 3, 3, 160)       0           ['batch_normalization_151[0][0]']
#
#  average_pooling2d_14 (AverageP  (8, 3, 3, 768)      0           ['mixed5[0][0]']
#  ooling2D)
#
#  conv2d_144 (Conv2D)            (8, 3, 3, 192)       147456      ['mixed5[0][0]']
#
#  conv2d_147 (Conv2D)            (8, 3, 3, 192)       215040      ['activation_146[0][0]']
#
#  conv2d_152 (Conv2D)            (8, 3, 3, 192)       215040      ['activation_151[0][0]']
#
#  conv2d_153 (Conv2D)            (8, 3, 3, 192)       147456      ['average_pooling2d_14[0][0]']
#
#  batch_normalization_144 (Batch  (8, 3, 3, 192)      576         ['conv2d_144[0][0]']
#  Normalization)
#
#  batch_normalization_147 (Batch  (8, 3, 3, 192)      576         ['conv2d_147[0][0]']
#  Normalization)
#
#  batch_normalization_152 (Batch  (8, 3, 3, 192)      576         ['conv2d_152[0][0]']
#  Normalization)
#
#  batch_normalization_153 (Batch  (8, 3, 3, 192)      576         ['conv2d_153[0][0]']
#  Normalization)
#
#  activation_144 (Activation)    (8, 3, 3, 192)       0           ['batch_normalization_144[0][0]']
#
#  activation_147 (Activation)    (8, 3, 3, 192)       0           ['batch_normalization_147[0][0]']
#
#  activation_152 (Activation)    (8, 3, 3, 192)       0           ['batch_normalization_152[0][0]']
#
#  activation_153 (Activation)    (8, 3, 3, 192)       0           ['batch_normalization_153[0][0]']
#
#  mixed6 (Concatenate)           (8, 3, 3, 768)       0           ['activation_144[0][0]',
#                                                                   'activation_147[0][0]',
#                                                                   'activation_152[0][0]',
#                                                                   'activation_153[0][0]']
#
#  conv2d_158 (Conv2D)            (8, 3, 3, 192)       147456      ['mixed6[0][0]']
# ...
#
#  activation_174 (Activation)    (8, 1, 1, 448)       0           ['batch_normalization_174[0][0]']
#
#  conv2d_171 (Conv2D)            (8, 1, 1, 384)       491520      ['mixed8[0][0]']
#
#  conv2d_175 (Conv2D)            (8, 1, 1, 384)       1548288     ['activation_174[0][0]']
#
#  batch_normalization_171 (Batch  (8, 1, 1, 384)      1152        ['conv2d_171[0][0]']
#  Normalization)
#
#  batch_normalization_175 (Batch  (8, 1, 1, 384)      1152        ['conv2d_175[0][0]']
#  Normalization)
#
#  activation_171 (Activation)    (8, 1, 1, 384)       0           ['batch_normalization_171[0][0]']
#
#  activation_175 (Activation)    (8, 1, 1, 384)       0           ['batch_normalization_175[0][0]']
#
#  conv2d_172 (Conv2D)            (8, 1, 1, 384)       442368      ['activation_171[0][0]']
#
#  conv2d_173 (Conv2D)            (8, 1, 1, 384)       442368      ['activation_171[0][0]']
#
#  conv2d_176 (Conv2D)            (8, 1, 1, 384)       442368      ['activation_175[0][0]']
#
#  conv2d_177 (Conv2D)            (8, 1, 1, 384)       442368      ['activation_175[0][0]']
#
#  average_pooling2d_16 (AverageP  (8, 1, 1, 1280)     0           ['mixed8[0][0]']
#  ooling2D)
#
#  conv2d_170 (Conv2D)            (8, 1, 1, 320)       409600      ['mixed8[0][0]']
#
#  batch_normalization_172 (Batch  (8, 1, 1, 384)      1152        ['conv2d_172[0][0]']
#  Normalization)
#
#  batch_normalization_173 (Batch  (8, 1, 1, 384)      1152        ['conv2d_173[0][0]']
#  Normalization)
#
#  batch_normalization_176 (Batch  (8, 1, 1, 384)      1152        ['conv2d_176[0][0]']
#  Normalization)
#
#  batch_normalization_177 (Batch  (8, 1, 1, 384)      1152        ['conv2d_177[0][0]']
#  Normalization)
#
#  conv2d_178 (Conv2D)            (8, 1, 1, 192)       245760      ['average_pooling2d_16[0][0]']
#
#  batch_normalization_170 (Batch  (8, 1, 1, 320)      960         ['conv2d_170[0][0]']
#  Normalization)
#
#  activation_172 (Activation)    (8, 1, 1, 384)       0           ['batch_normalization_172[0][0]']
#
#  activation_173 (Activation)    (8, 1, 1, 384)       0           ['batch_normalization_173[0][0]']
#
#  activation_176 (Activation)    (8, 1, 1, 384)       0           ['batch_normalization_176[0][0]']
#
#  activation_177 (Activation)    (8, 1, 1, 384)       0           ['batch_normalization_177[0][0]']
#
#  batch_normalization_178 (Batch  (8, 1, 1, 192)      576         ['conv2d_178[0][0]']
#  Normalization)
#
#  activation_170 (Activation)    (8, 1, 1, 320)       0           ['batch_normalization_170[0][0]']
#
#  mixed9_0 (Concatenate)         (8, 1, 1, 768)       0           ['activation_172[0][0]',
#                                                                   'activation_173[0][0]']
#
#  concatenate_2 (Concatenate)    (8, 1, 1, 768)       0           ['activation_176[0][0]',
#                                                                   'activation_177[0][0]']
#
#  activation_178 (Activation)    (8, 1, 1, 192)       0           ['batch_normalization_178[0][0]']
#
#  mixed9 (Concatenate)           (8, 1, 1, 2048)      0           ['activation_170[0][0]',
#                                                                   'mixed9_0[0][0]',
#                                                                   'concatenate_2[0][0]',
#                                                                   'activation_178[0][0]']
#
#  conv2d_183 (Conv2D)            (8, 1, 1, 448)       917504      ['mixed9[0][0]']
#
#  batch_normalization_183 (Batch  (8, 1, 1, 448)      1344        ['conv2d_183[0][0]']
#  Normalization)
#
#  activation_183 (Activation)    (8, 1, 1, 448)       0           ['batch_normalization_183[0][0]']
#
#  conv2d_180 (Conv2D)            (8, 1, 1, 384)       786432      ['mixed9[0][0]']
#
#  conv2d_184 (Conv2D)            (8, 1, 1, 384)       1548288     ['activation_183[0][0]']
#
#  batch_normalization_180 (Batch  (8, 1, 1, 384)      1152        ['conv2d_180[0][0]']
#  Normalization)
#
#  batch_normalization_184 (Batch  (8, 1, 1, 384)      1152        ['conv2d_184[0][0]']
#  Normalization)
#
#  activation_180 (Activation)    (8, 1, 1, 384)       0           ['batch_normalization_180[0][0]']
#
#  activation_184 (Activation)    (8, 1, 1, 384)       0           ['batch_normalization_184[0][0]']
#
#  conv2d_181 (Conv2D)            (8, 1, 1, 384)       442368      ['activation_180[0][0]']
#
#  conv2d_182 (Conv2D)            (8, 1, 1, 384)       442368      ['activation_180[0][0]']
#
#  conv2d_185 (Conv2D)            (8, 1, 1, 384)       442368      ['activation_184[0][0]']
#
#  conv2d_186 (Conv2D)            (8, 1, 1, 384)       442368      ['activation_184[0][0]']
#
#  average_pooling2d_17 (AverageP  (8, 1, 1, 2048)     0           ['mixed9[0][0]']
#  ooling2D)
#
#  conv2d_179 (Conv2D)            (8, 1, 1, 320)       655360      ['mixed9[0][0]']
#
#  batch_normalization_181 (Batch  (8, 1, 1, 384)      1152        ['conv2d_181[0][0]']
#  Normalization)
#
#  batch_normalization_182 (Batch  (8, 1, 1, 384)      1152        ['conv2d_182[0][0]']
#  Normalization)
#
#  batch_normalization_185 (Batch  (8, 1, 1, 384)      1152        ['conv2d_185[0][0]']
#  Normalization)
#
#  batch_normalization_186 (Batch  (8, 1, 1, 384)      1152        ['conv2d_186[0][0]']
#  Normalization)
#
#  conv2d_187 (Conv2D)            (8, 1, 1, 192)       393216      ['average_pooling2d_17[0][0]']
#
#  batch_normalization_179 (Batch  (8, 1, 1, 320)      960         ['conv2d_179[0][0]']
#  Normalization)
#
#  activation_181 (Activation)    (8, 1, 1, 384)       0           ['batch_normalization_181[0][0]']
#
#  activation_182 (Activation)    (8, 1, 1, 384)       0           ['batch_normalization_182[0][0]']
#
#  activation_185 (Activation)    (8, 1, 1, 384)       0           ['batch_normalization_185[0][0]']
#
#  activation_186 (Activation)    (8, 1, 1, 384)       0           ['batch_normalization_186[0][0]']
#
#  batch_normalization_187 (Batch  (8, 1, 1, 192)      576         ['conv2d_187[0][0]']
#  Normalization)
#
#  activation_179 (Activation)    (8, 1, 1, 320)       0           ['batch_normalization_179[0][0]']
#
#  mixed9_1 (Concatenate)         (8, 1, 1, 768)       0           ['activation_181[0][0]',
#                                                                   'activation_182[0][0]']
#
#  concatenate_3 (Concatenate)    (8, 1, 1, 768)       0           ['activation_185[0][0]',
#                                                                   'activation_186[0][0]']
#
#  activation_187 (Activation)    (8, 1, 1, 192)       0           ['batch_normalization_187[0][0]']
#
#  mixed10 (Concatenate)          (8, 1, 1, 2048)      0           ['activation_179[0][0]',
#                                                                   'mixed9_1[0][0]',
#                                                                   'concatenate_3[0][0]',
#                                                                   'activation_187[0][0]']
#
#  flatten_1 (Flatten)            (8, 2048)            0           ['mixed10[0][0]']
#
#  dense_2 (Dense)                (8, 64)              131136      ['flatten_1[0][0]']
#
#  dropout_1 (Dropout)            (8, 64)              0           ['dense_2[0][0]']
#
#  dense_3 (Dense)                (8, 2)               130         ['dropout_1[0][0]']
#
# ==================================================================================================
# Total params: 21,934,050
# Trainable params: 131,266
# Non-trainable params: 21,802,784
# __________________________________________________________________________________________________

# %%
from tensorflow.keras.callbacks import ModelCheckpoint,EarlyStopping, ReduceLROnPlateau

# %%
checkpoint = ModelCheckpoint(r'D:\dataset\model\model.h5',
                            monitor='val_loss',save_best_only=True,verbose=3)

earlystop = EarlyStopping(monitor = 'val_loss', patience=7, verbose= 3, restore_best_weights=True)

learning_rate = ReduceLROnPlateau(monitor= 'val_loss', patience=3, verbose= 3, )

callbacks=[checkpoint,earlystop,learning_rate]

# %%
model.compile(optimizer='Adam', loss='categorical_crossentropy',metrics=['accuracy'])

model.fit_generator(train_data,steps_per_epoch=train_data.samples//batchsize,
                   validation_data=validation_data,
                   validation_steps=validation_data.samples//batchsize,
                   callbacks=callbacks,
                    epochs=2)
# Out:
# <ipython-input-34-c4e3d058002e>:3: UserWarning: `Model.fit_generator` is deprecated and will be removed in a future version. Please use `Model.fit`, which supports generators.
#   model.fit_generator(train_data,steps_per_epoch=train_data.samples//batchsize,
# Epoch 1/2
# 4316/8017 [===============>..............] - ETA: 10:41 - loss: 0.1959 - accuracy: 0.9253
# ---------------------------------------------------------------------------
# InvalidArgumentError                      Traceback (most recent call last)
# <ipython-input-34-c4e3d058002e> in <module>
#       1 model.compile(optimizer='Adam', loss='categorical_crossentropy',metrics=['accuracy'])
#       2
# ----> 3 model.fit_generator(train_data,steps_per_epoch=train_data.samples//batchsize,
#       4                    validation_data=validation_data,
#       5                    validation_steps=validation_data.samples//batchsize,
#
# ~\anaconda3\lib\site-packages\keras\engine\training.py in fit_generator(self, generator, steps_per_epoch, epochs, verbose, callbacks, validation_data, validation_steps, validation_freq, class_weight, max_queue_size, workers, use_multiprocessing, shuffle, initial_epoch)
#    2014         'Please use `Model.fit`, which supports generators.',
#    2015         stacklevel=2)
# -> 2016     return self.fit(
#    2017         generator,
#    2018         steps_per_epoch=steps_per_epoch,
#
# ~\anaconda3\lib\site-packages\keras\utils\traceback_utils.py in error_handler(*args, **kwargs)
#      65     except Exception as e:  # pylint: disable=broad-except
#      66       filtered_tb = _process_traceback_frames(e.__traceback__)
# ---> 67       raise e.with_traceback(filtered_tb) from None
#      68     finally:
#      69       del filtered_tb
#
# ~\anaconda3\lib\site-packages\tensorflow\python\eager\execute.py in quick_execute(op_name, num_outputs, inputs, attrs, ctx, name)
#      56   try:
#      57     ctx.ensure_initialized()
# ---> 58     tensors = pywrap_tfe.TFE_Py_Execute(ctx._handle, device_name, op_name,
#      59                                         inputs, attrs, num_outputs)
#      60   except core._NotOkStatusException as e:
#
# InvalidArgumentError:  Incompatible shapes: [7,64] vs. [8,64]
# 	 [[node model_1/dropout_1/dropout/Mul_1
#  (defined at C:\Users\ASUS\anaconda3\lib\site-packages\keras\layers\core\dropout.py:105)
# ]] [Op:__inference_train_function_56020]
#
# Errors may have originated from an input operation.
# Input Source operations connected to node model_1/dropout_1/dropout/Mul_1:
# In[0] model_1/dropout_1/dropout/Mul:
# In[1] model_1/dropout_1/dropout/Cast:
#
# Operation defined at: (most recent call last)
# >>>   File "C:\Users\ASUS\anaconda3\lib\runpy.py", line 194, in _run_module_as_main
# >>>     return _run_code(code, main_globals, None,
# >>>
# >>>   File "C:\Users\ASUS\anaconda3\lib\runpy.py", line 87, in _run_code
# >>>     exec(code, run_globals)
# >>>
# >>>   File "C:\Users\ASUS\anaconda3\lib\site-packages\ipykernel_launcher.py", line 16, in <module>
# >>>     app.launch_new_instance()
# >>>
# >>>   File "C:\Users\ASUS\anaconda3\lib\site-packages\traitlets\config\application.py", line 845, in launch_instance
# >>>     app.start()
# >>>
# >>>   File "C:\Users\ASUS\anaconda3\lib\site-packages\ipykernel\kernelapp.py", line 612, in start
# >>>     self.io_loop.start()
# >>>
# >>>   File "C:\Users\ASUS\anaconda3\lib\site-packages\tornado\platform\asyncio.py", line 199, in start
# >>>     self.asyncio_loop.run_forever()
# >>>
# >>>   File "C:\Users\ASUS\anaconda3\lib\asyncio\base_events.py", line 570, in run_forever
# >>>     self._run_once()
# >>>
# >>>   File "C:\Users\ASUS\anaconda3\lib\asyncio\base_events.py", line 1859, in _run_once
# >>>     handle._run()
# >>>
# >>>   File "C:\Users\ASUS\anaconda3\lib\asyncio\events.py", line 81, in _run
# >>>     self._context.run(self._callback, *self._args)
# >>>
# >>>   File "C:\Users\ASUS\anaconda3\lib\site-packages\tornado\ioloop.py", line 688, in <lambda>
# >>>     lambda f: self._run_callback(functools.partial(callback, future))
# >>>
# >>>   File "C:\Users\ASUS\anaconda3\lib\site-packages\tornado\ioloop.py", line 741, in _run_callback
# >>>     ret = callback()
# >>>
# >>>   File "C:\Users\ASUS\anaconda3\lib\site-packages\tornado\gen.py", line 814, in inner
# >>>     self.ctx_run(self.run)
# >>>
# >>>   File "C:\Users\ASUS\anaconda3\lib\site-packages\tornado\gen.py", line 775, in run
# >>>     yielded = self.gen.send(value)
# >>>
# >>>   File "C:\Users\ASUS\anaconda3\lib\site-packages\ipykernel\kernelbase.py", line 365, in process_one
# >>>     yield gen.maybe_future(dispatch(*args))
# >>>
# >>>   File "C:\Users\ASUS\anaconda3\lib\site-packages\tornado\gen.py", line 234, in wrapper
# >>>     yielded = ctx_run(next, result)
# >>>
# >>>   File "C:\Users\ASUS\anaconda3\lib\site-packages\ipykernel\kernelbase.py", line 268, in dispatch_shell
# >>>     yield gen.maybe_future(handler(stream, idents, msg))
# >>>
# >>>   File "C:\Users\ASUS\anaconda3\lib\site-packages\tornado\gen.py", line 234, in wrapper
# >>>     yielded = ctx_run(next, result)
# >>>
# >>>   File "C:\Users\ASUS\anaconda3\lib\site-packages\ipykernel\kernelbase.py", line 543, in execute_request
# >>>     self.do_execute(
# >>>
# >>>   File "C:\Users\ASUS\anaconda3\lib\site-packages\tornado\gen.py", line 234, in wrapper
# >>>     yielded = ctx_run(next, result)
# >>>
# >>>   File "C:\Users\ASUS\anaconda3\lib\site-packages\ipykernel\ipkernel.py", line 306, in do_execute
# >>>     res = shell.run_cell(code, store_history=store_history, silent=silent)
# >>>
# >>>   File "C:\Users\ASUS\anaconda3\lib\site-packages\ipykernel\zmqshell.py", line 536, in run_cell
# >>>     return super(ZMQInteractiveShell, self).run_cell(*args, **kwargs)
# >>>
# >>>   File "C:\Users\ASUS\anaconda3\lib\site-packages\IPython\core\interactiveshell.py", line 2894, in run_cell
# >>>     result = self._run_cell(
# >>>
# >>>   File "C:\Users\ASUS\anaconda3\lib\site-packages\IPython\core\interactiveshell.py", line 2940, in _run_cell
# >>>     return runner(coro)
# >>>
# >>>   File "C:\Users\ASUS\anaconda3\lib\site-packages\IPython\core\async_helpers.py", line 68, in _pseudo_sync_runner
# >>>     coro.send(None)
# >>>
# >>>   File "C:\Users\ASUS\anaconda3\lib\site-packages\IPython\core\interactiveshell.py", line 3165, in run_cell_async
# >>>     has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
# >>>
# >>>   File "C:\Users\ASUS\anaconda3\lib\site-packages\IPython\core\interactiveshell.py", line 3357, in run_ast_nodes
# >>>     if (await self.run_code(code, result,  async_=asy)):
# >>>
# >>>   File "C:\Users\ASUS\anaconda3\lib\site-packages\IPython\core\interactiveshell.py", line 3437, in run_code
# >>>     exec(code_obj, self.user_global_ns, self.user_ns)
# >>>
# >>>   File "<ipython-input-34-c4e3d058002e>", line 3, in <module>
# >>>     model.fit_generator(train_data,steps_per_epoch=train_data.samples//batchsize,
# >>>
# >>>   File "C:\Users\ASUS\anaconda3\lib\site-packages\keras\engine\training.py", line 2016, in fit_generator
# >>>     return self.fit(
# >>>
# >>>   File "C:\Users\ASUS\anaconda3\lib\site-packages\keras\utils\traceback_utils.py", line 64, in error_handler
# >>>     return fn(*args, **kwargs)
# >>>
# >>>   File "C:\Users\ASUS\anaconda3\lib\site-packages\keras\engine\training.py", line 1216, in fit
# >>>     tmp_logs = self.train_function(iterator)
# >>>
# >>>   File "C:\Users\ASUS\anaconda3\lib\site-packages\keras\engine\training.py", line 878, in train_function
# >>>     return step_function(self, iterator)
# >>>
# >>>   File "C:\Users\ASUS\anaconda3\lib\site-packages\keras\engine\training.py", line 867, in step_function
# >>>     outputs = model.distribute_strategy.run(run_step, args=(data,))
# >>>
# >>>   File "C:\Users\ASUS\anaconda3\lib\site-packages\keras\engine\training.py", line 860, in run_step
# >>>     outputs = model.train_step(data)
# >>>
# >>>   File "C:\Users\ASUS\anaconda3\lib\site-packages\keras\engine\training.py", line 808, in train_step
# >>>     y_pred = self(x, training=True)
# >>>
# >>>   File "C:\Users\ASUS\anaconda3\lib\site-packages\keras\utils\traceback_utils.py", line 64, in error_handler
# >>>     return fn(*args, **kwargs)
# >>>
# >>>   File "C:\Users\ASUS\anaconda3\lib\site-packages\keras\engine\base_layer.py", line 1083, in __call__
# >>>     outputs = call_fn(inputs, *args, **kwargs)
# >>>
# >>>   File "C:\Users\ASUS\anaconda3\lib\site-packages\keras\utils\traceback_utils.py", line 92, in error_handler
# >>>     return fn(*args, **kwargs)
# >>>
# >>>   File "C:\Users\ASUS\anaconda3\lib\site-packages\keras\engine\functional.py", line 451, in call
# >>>     return self._run_internal_graph(
# >>>
# >>>   File "C:\Users\ASUS\anaconda3\lib\site-packages\keras\engine\functional.py", line 589, in _run_internal_graph
# >>>     outputs = node.layer(*args, **kwargs)
# >>>
# >>>   File "C:\Users\ASUS\anaconda3\lib\site-packages\keras\utils\traceback_utils.py", line 64, in error_handler
# >>>     return fn(*args, **kwargs)
# >>>
# >>>   File "C:\Users\ASUS\anaconda3\lib\site-packages\keras\engine\base_layer.py", line 1083, in __call__
# >>>     outputs = call_fn(inputs, *args, **kwargs)
# >>>
# >>>   File "C:\Users\ASUS\anaconda3\lib\site-packages\keras\utils\traceback_utils.py", line 92, in error_handler
# >>>     return fn(*args, **kwargs)
# >>>
# >>>   File "C:\Users\ASUS\anaconda3\lib\site-packages\keras\layers\core\dropout.py", line 111, in call
# >>>     output = control_flow_util.smart_cond(training, dropped_inputs,
# >>>
# >>>   File "C:\Users\ASUS\anaconda3\lib\site-packages\keras\utils\control_flow_util.py", line 105, in smart_cond
# >>>     return tf.__internal__.smart_cond.smart_cond(
# >>>
# >>>   File "C:\Users\ASUS\anaconda3\lib\site-packages\keras\layers\core\dropout.py", line 105, in dropped_inputs
# >>>     return tf.nn.dropout(
# >>>

# %%
acc_tr, loss_tr = model.evaluate_generator(train_data)
print(acc_tr)
print(loss_tr)

# %%
acc_vr, loss_vr = model.evaluate_generator(validation_data)
print(acc_vr)
print(loss_vr)

# %%
acc_test, loss_test = model.evaluate_generator(test_data)
print(acc_tr)
print(loss_tr)
